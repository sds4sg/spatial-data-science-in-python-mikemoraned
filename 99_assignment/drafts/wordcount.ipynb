# %%
import io
import os
from nbformat import current

total_markdown = 0
total_heading = 0
total_code = 0

for root, dirs, files in os.walk("."):
    for file in files:
        if file.endswith(".ipynb") and not file.endswith("checkpoint.ipynb") :
            with io.open(os.path.join(root, file), 'r', encoding='utf-8') as f:
                nb = current.read(f, 'json')

            word_count_markdown = 0
            word_count_heading = 0
            word_count_code = 0
            for cell in nb.worksheets[0].cells:
                if cell.cell_type == "markdown":
                    word_count_markdown += len(cell['source'].replace('#', '').lstrip().split(' '))
                elif cell.cell_type == "heading":
                    word_count_heading += len(cell['source'].replace('#', '').lstrip().split(' '))
                elif cell.cell_type == "code":
                    word_count_code += len(cell['input'].replace('#', '').lstrip().split(' '))
            total_markdown += word_count_markdown
            total_heading += word_count_heading
            total_code += word_count_code

            print(f"{os.path.join(root, file)}: {total_markdown}, {total_code}")
# Out:
# ./part1_draft4_1.ipynb: 0, 1035
# ./part1_draft4.ipynb: 0, 2119
# ./assignment_v1_part1.ipynb: 542, 2997
# ./combined_draft1.ipynb: 701, 4731
# ./part1_draft2.ipynb: 701, 5187
# ./part1_draft5.ipynb: 701, 6375
# ./wordcount.ipynb: 701, 6692
# ./part1_draft3.ipynb: 701, 7747
# ./part1_draft1.ipynb: 747, 7951
# ./part2_2_draft5.ipynb: 747, 8938
# ./barcelona_context.ipynb: 747, 9062
# ./part2_2_draft7_reg.ipynb: 821, 10918
# ./part2_2_draft3.ipynb: 821, 11733
# ./part2_2_draft1.ipynb: 882, 12400
# ./part2_2_draft6.ipynb: 882, 12821
# ./part2_2_draft4.ipynb: 882, 13794
# ./esda1.ipynb: 1038, 13937
# ./part2_2_draft2.ipynb: 1038, 14598
